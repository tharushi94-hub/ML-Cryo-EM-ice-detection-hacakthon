# %%
from pathlib import Path
import pandas as pd
import numpy as np
import mrcfile
from scipy.spatial import cKDTree
import matplotlib.pyplot as plt
import imageio.v2 as imageio

# %%
####Loading directories
main_dir=Path("/home/tharushi/Desktop/hackathon/10061")
false_positive_dir=main_dir/"ground_truth/false_positives"
particle_coord_dir=main_dir/"ground_truth/particle_coordinates"
micrograph_dir=main_dir/"micrographs"

# %%
###building micrographs, particle csv,false_positive csv mapping
def extract_stack_id(filename):
    return filename.split("_Fractions")[0]


micrographs = {
    extract_stack_id(f.name): f
    for f in micrograph_dir.glob("*.mrc")   # or *.tif
}

false_positives = {
    extract_stack_id(f.name): f
    for f in false_positive_dir.glob("*.csv")
}

particle_coords = {
    extract_stack_id(f.name): f
    for f in particle_coord_dir.glob("*.csv")
}


valid_ids = (
    micrographs.keys()
    & false_positives.keys()
    & particle_coords.keys()
)
for stack_id in sorted(valid_ids):
    img_path = micrographs[stack_id]
    fp_csv = false_positives[stack_id]
    pc_csv = particle_coords[stack_id]

    print(f"\n{stack_id}")
    print("  Micrograph:", img_path.name)
    print("  False positives:", fp_csv.name)
    print("  Particles:", pc_csv.name)

# %%
'''
def extract_stack_id(name: str) -> str:
    # remove known suffix first
    if name.endswith("_false_positives.csv"):
        name = name.replace("_false_positives.csv", "")
    else:
        name = Path(name).stem  # removes .mrc or .csv

    # now remove the trailing "_0" only (not "_09", etc.)
    if name.endswith("_0"):
        name = name[:-2]  # drop last 2 chars: "_0"
    return name
'''


def extract_stack_id(filename):
    name = Path(filename).stem
    if name.endswith("_false_positives"):
        name = name.replace("_false_positives", "")
    return name

micrographs = {
    extract_stack_id(f.name): f
    for f in micrograph_dir.glob("*.mrc")   # or *.tif
}

false_positives = {
    extract_stack_id(f.name): f
    for f in false_positive_dir.glob("*.csv")
}

particle_coords = {
    extract_stack_id(f.name): f
    for f in particle_coord_dir.glob("*.csv")
}


valid_ids = (
    micrographs.keys()
    & false_positives.keys()
    & particle_coords.keys()
)
for stack_id in sorted(valid_ids):
    img_path = micrographs[stack_id]
    fp_csv = false_positives[stack_id]
    pc_csv = particle_coords[stack_id]

    print(f"\n{stack_id}")
    print("  Micrograph:", img_path.name)
    print("  False positives:", fp_csv.name)
    print("  Particles:", pc_csv.name)
# Out:
# EMD-2984_0035
#   Micrograph: EMD-2984_0035.mrc
#   False positives: EMD-2984_0035_false_positives.csv
#   Particles: EMD-2984_0035.csv
#
# EMD-2984_0036
#   Micrograph: EMD-2984_0036.mrc
#   False positives: EMD-2984_0036_false_positives.csv
#   Particles: EMD-2984_0036.csv
#
# EMD-2984_0037
#   Micrograph: EMD-2984_0037.mrc
#   False positives: EMD-2984_0037_false_positives.csv
#   Particles: EMD-2984_0037.csv
#
# EMD-2984_0038
#   Micrograph: EMD-2984_0038.mrc
#   False positives: EMD-2984_0038_false_positives.csv
#   Particles: EMD-2984_0038.csv
#
# EMD-2984_0039
#   Micrograph: EMD-2984_0039.mrc
#   False positives: EMD-2984_0039_false_positives.csv
#   Particles: EMD-2984_0039.csv
#
# EMD-2984_0040
#   Micrograph: EMD-2984_0040.mrc
#   False positives: EMD-2984_0040_false_positives.csv
#   Particles: EMD-2984_0040.csv
#
# EMD-2984_0041
#   Micrograph: EMD-2984_0041.mrc
#   False positives: EMD-2984_0041_false_positives.csv
#   Particles: EMD-2984_0041.csv
#
# EMD-2984_0042
#   Micrograph: EMD-2984_0042.mrc
#   False positives: EMD-2984_0042_false_positives.csv
#   Particles: EMD-2984_0042.csv
#
# EMD-2984_0043
#   Micrograph: EMD-2984_0043.mrc
#   False positives: EMD-2984_0043_false_positives.csv
#   Particles: EMD-2984_0043.csv
#
# EMD-2984_0044
#   Micrograph: EMD-2984_0044.mrc
#   False positives: EMD-2984_0044_false_positives.csv
#   Particles: EMD-2984_0044.csv
#
# EMD-2984_0045
#   Micrograph: EMD-2984_0045.mrc
#   False positives: EMD-2984_0045_false_positives.csv
#   Particles: EMD-2984_0045.csv
#
# EMD-2984_0046
#   Micrograph: EMD-2984_0046.mrc
#   False positives: EMD-2984_0046_false_positives.csv
#   Particles: EMD-2984_0046.csv
#
# EMD-2984_0047
#   Micrograph: EMD-2984_0047.mrc
#   False positives: EMD-2984_0047_false_positives.csv
#   Particles: EMD-2984_0047.csv
#
# EMD-2984_0048
#   Micrograph: EMD-2984_0048.mrc
#   False positives: EMD-2984_0048_false_positives.csv
#   Particles: EMD-2984_0048.csv
#
# EMD-2984_0049
#   Micrograph: EMD-2984_0049.mrc
#   False positives: EMD-2984_0049_false_positives.csv
#   Particles: EMD-2984_0049.csv
#
# EMD-2984_0050
#   Micrograph: EMD-2984_0050.mrc
#   False positives: EMD-2984_0050_false_positives.csv
#   Particles: EMD-2984_0050.csv
#
# EMD-2984_0051
#   Micrograph: EMD-2984_0051.mrc
#   False positives: EMD-2984_0051_false_positives.csv
#   Particles: EMD-2984_0051.csv
#
# EMD-2984_0052
#   Micrograph: EMD-2984_0052.mrc
#   False positives: EMD-2984_0052_false_positives.csv
#   Particles: EMD-2984_0052.csv
#
# EMD-2984_0053
#   Micrograph: EMD-2984_0053.mrc
#   False positives: EMD-2984_0053_false_positives.csv
#   Particles: EMD-2984_0053.csv
#
# EMD-2984_0054
#   Micrograph: EMD-2984_0054.mrc
#   False positives: EMD-2984_0054_false_positives.csv
#   Particles: EMD-2984_0054.csv
#
# EMD-2984_0055
#   Micrograph: EMD-2984_0055.mrc
#   False positives: EMD-2984_0055_false_positives.csv
#   Particles: EMD-2984_0055.csv
#
# EMD-2984_0056
#   Micrograph: EMD-2984_0056.mrc
#   False positives: EMD-2984_0056_false_positives.csv
#   Particles: EMD-2984_0056.csv
#
# EMD-2984_0057
#   Micrograph: EMD-2984_0057.mrc
#   False positives: EMD-2984_0057_false_positives.csv
#   Particles: EMD-2984_0057.csv
#
# EMD-2984_0058
#   Micrograph: EMD-2984_0058.mrc
#   False positives: EMD-2984_0058_false_positives.csv
#   Particles: EMD-2984_0058.csv
#
# EMD-2984_0059
#   Micrograph: EMD-2984_0059.mrc
#   False positives: EMD-2984_0059_false_positives.csv
#   Particles: EMD-2984_0059.csv
#
# EMD-2984_0060
#   Micrograph: EMD-2984_0060.mrc
#   False positives: EMD-2984_0060_false_positives.csv
#   Particles: EMD-2984_0060.csv
#
# EMD-2984_0061
#   Micrograph: EMD-2984_0061.mrc
#   False positives: EMD-2984_0061_false_positives.csv
#   Particles: EMD-2984_0061.csv
#
# EMD-2984_0062
#   Micrograph: EMD-2984_0062.mrc
#   False positives: EMD-2984_0062_false_positives.csv
#   Particles: EMD-2984_0062.csv
#
# EMD-2984_0063
#   Micrograph: EMD-2984_0063.mrc
#   False positives: EMD-2984_0063_false_positives.csv
#   Particles: EMD-2984_0063.csv
#
# EMD-2984_0064
#   Micrograph: EMD-2984_0064.mrc
#   False positives: EMD-2984_0064_false_positives.csv
#   Particles: EMD-2984_0064.csv
#
# EMD-2984_0065
#   Micrograph: EMD-2984_0065.mrc
#   False positives: EMD-2984_0065_false_positives.csv
#   Particles: EMD-2984_0065.csv
#
# EMD-2984_0066
#   Micrograph: EMD-2984_0066.mrc
#   False positives: EMD-2984_0066_false_positives.csv
#   Particles: EMD-2984_0066.csv
#
# EMD-2984_0067
#   Micrograph: EMD-2984_0067.mrc
#   False positives: EMD-2984_0067_false_positives.csv
#   Particles: EMD-2984_0067.csv
#
# EMD-2984_0068
#   Micrograph: EMD-2984_0068.mrc
#   False positives: EMD-2984_0068_false_positives.csv
#   Particles: EMD-2984_0068.csv
#
# EMD-2984_0069
#   Micrograph: EMD-2984_0069.mrc
#   False positives: EMD-2984_0069_false_positives.csv
#   Particles: EMD-2984_0069.csv
#
# EMD-2984_0070
#   Micrograph: EMD-2984_0070.mrc
#   False positives: EMD-2984_0070_false_positives.csv
#   Particles: EMD-2984_0070.csv
#
# EMD-2984_0071
#   Micrograph: EMD-2984_0071.mrc
#   False positives: EMD-2984_0071_false_positives.csv
#   Particles: EMD-2984_0071.csv
#
# EMD-2984_0072
#   Micrograph: EMD-2984_0072.mrc
#   False positives: EMD-2984_0072_false_positives.csv
#   Particles: EMD-2984_0072.csv
#
# EMD-2984_0073
#   Micrograph: EMD-2984_0073.mrc
#   False positives: EMD-2984_0073_false_positives.csv
#   Particles: EMD-2984_0073.csv
#
# EMD-2984_0074
#   Micrograph: EMD-2984_0074.mrc
#   False positives: EMD-2984_0074_false_positives.csv
#   Particles: EMD-2984_0074.csv
#
# EMD-2984_0075
#   Micrograph: EMD-2984_0075.mrc
#   False positives: EMD-2984_0075_false_positives.csv
#   Particles: EMD-2984_0075.csv
#
# EMD-2984_0076
#   Micrograph: EMD-2984_0076.mrc
#   False positives: EMD-2984_0076_false_positives.csv
#   Particles: EMD-2984_0076.csv
#
# EMD-2984_0077
#   Micrograph: EMD-2984_0077.mrc
#   False positives: EMD-2984_0077_false_positives.csv
#   Particles: EMD-2984_0077.csv
#
# EMD-2984_0078
#   Micrograph: EMD-2984_0078.mrc
#   False positives: EMD-2984_0078_false_positives.csv
#   Particles: EMD-2984_0078.csv
#
# EMD-2984_0079
#   Micrograph: EMD-2984_0079.mrc
#   False positives: EMD-2984_0079_false_positives.csv
#   Particles: EMD-2984_0079.csv
#
# EMD-2984_0080
#   Micrograph: EMD-2984_0080.mrc
#   False positives: EMD-2984_0080_false_positives.csv
#   Particles: EMD-2984_0080.csv
#
# EMD-2984_0081
#   Micrograph: EMD-2984_0081.mrc
#   False positives: EMD-2984_0081_false_positives.csv
#   Particles: EMD-2984_0081.csv
#
# EMD-2984_0082
#   Micrograph: EMD-2984_0082.mrc
#   False positives: EMD-2984_0082_false_positives.csv
#   Particles: EMD-2984_0082.csv
#
# EMD-2984_0083
#   Micrograph: EMD-2984_0083.mrc
#   False positives: EMD-2984_0083_false_positives.csv
#   Particles: EMD-2984_0083.csv
#
# EMD-2984_0084
#   Micrograph: EMD-2984_0084.mrc
#   False positives: EMD-2984_0084_false_positives.csv
#   Particles: EMD-2984_0084.csv
#
# EMD-2984_0085
#   Micrograph: EMD-2984_0085.mrc
#   False positives: EMD-2984_0085_false_positives.csv
#   Particles: EMD-2984_0085.csv
#
# EMD-2984_0086
#   Micrograph: EMD-2984_0086.mrc
#   False positives: EMD-2984_0086_false_positives.csv
#   Particles: EMD-2984_0086.csv
#
# EMD-2984_0087
#   Micrograph: EMD-2984_0087.mrc
#   False positives: EMD-2984_0087_false_positives.csv
#   Particles: EMD-2984_0087.csv
#
# EMD-2984_0088
#   Micrograph: EMD-2984_0088.mrc
#   False positives: EMD-2984_0088_false_positives.csv
#   Particles: EMD-2984_0088.csv
#
# EMD-2984_0089
#   Micrograph: EMD-2984_0089.mrc
#   False positives: EMD-2984_0089_false_positives.csv
#   Particles: EMD-2984_0089.csv
#
# EMD-2984_0090
#   Micrograph: EMD-2984_0090.mrc
#   False positives: EMD-2984_0090_false_positives.csv
#   Particles: EMD-2984_0090.csv
#
# EMD-2984_0091
#   Micrograph: EMD-2984_0091.mrc
#   False positives: EMD-2984_0091_false_positives.csv
#   Particles: EMD-2984_0091.csv
#
# EMD-2984_0092
#   Micrograph: EMD-2984_0092.mrc
#   False positives: EMD-2984_0092_false_positives.csv
#   Particles: EMD-2984_0092.csv
#
# EMD-2984_0093
#   Micrograph: EMD-2984_0093.mrc
#   False positives: EMD-2984_0093_false_positives.csv
#   Particles: EMD-2984_0093.csv
#
# EMD-2984_0094
#   Micrograph: EMD-2984_0094.mrc
#   False positives: EMD-2984_0094_false_positives.csv
#   Particles: EMD-2984_0094.csv
#
# EMD-2984_0095
#   Micrograph: EMD-2984_0095.mrc
#   False positives: EMD-2984_0095_false_positives.csv
#   Particles: EMD-2984_0095.csv
#
# EMD-2984_0096
#   Micrograph: EMD-2984_0096.mrc
#   False positives: EMD-2984_0096_false_positives.csv
#   Particles: EMD-2984_0096.csv
#
# EMD-2984_0097
#   Micrograph: EMD-2984_0097.mrc
#   False positives: EMD-2984_0097_false_positives.csv
#   Particles: EMD-2984_0097.csv
#
# EMD-2984_0098
#   Micrograph: EMD-2984_0098.mrc
#   False positives: EMD-2984_0098_false_positives.csv
#   Particles: EMD-2984_0098.csv
#
# EMD-2984_0099
#   Micrograph: EMD-2984_0099.mrc
#   False positives: EMD-2984_0099_false_positives.csv
#   Particles: EMD-2984_0099.csv
#
# EMD-2984_0100
#   Micrograph: EMD-2984_0100.mrc
#   False positives: EMD-2984_0100_false_positives.csv
#   Particles: EMD-2984_0100.csv
#
# EMD-2984_0101
#   Micrograph: EMD-2984_0101.mrc
#   False positives: EMD-2984_0101_false_positives.csv
#   Particles: EMD-2984_0101.csv
#
# EMD-2984_0102
#   Micrograph: EMD-2984_0102.mrc
#   False positives: EMD-2984_0102_false_positives.csv
#   Particles: EMD-2984_0102.csv
#
# EMD-2984_0103
#   Micrograph: EMD-2984_0103.mrc
#   False positives: EMD-2984_0103_false_positives.csv
#   Particles: EMD-2984_0103.csv
#
# EMD-2984_0104
#   Micrograph: EMD-2984_0104.mrc
#   False positives: EMD-2984_0104_false_positives.csv
#   Particles: EMD-2984_0104.csv
#
# EMD-2984_0105
#   Micrograph: EMD-2984_0105.mrc
#   False positives: EMD-2984_0105_false_positives.csv
#   Particles: EMD-2984_0105.csv
#
# EMD-2984_0106
#   Micrograph: EMD-2984_0106.mrc
#   False positives: EMD-2984_0106_false_positives.csv
#   Particles: EMD-2984_0106.csv
#
# EMD-2984_0107
#   Micrograph: EMD-2984_0107.mrc
#   False positives: EMD-2984_0107_false_positives.csv
#   Particles: EMD-2984_0107.csv
#
# EMD-2984_0108
#   Micrograph: EMD-2984_0108.mrc
#   False positives: EMD-2984_0108_false_positives.csv
#   Particles: EMD-2984_0108.csv
#
# EMD-2984_0109
#   Micrograph: EMD-2984_0109.mrc
#   False positives: EMD-2984_0109_false_positives.csv
#   Particles: EMD-2984_0109.csv
#
# EMD-2984_0110
#   Micrograph: EMD-2984_0110.mrc
#   False positives: EMD-2984_0110_false_positives.csv
#   Particles: EMD-2984_0110.csv
#
# EMD-2984_0111
#   Micrograph: EMD-2984_0111.mrc
#   False positives: EMD-2984_0111_false_positives.csv
#   Particles: EMD-2984_0111.csv
#
# EMD-2984_0112
#   Micrograph: EMD-2984_0112.mrc
#   False positives: EMD-2984_0112_false_positives.csv
#   Particles: EMD-2984_0112.csv
#
# EMD-2984_0113
#   Micrograph: EMD-2984_0113.mrc
#   False positives: EMD-2984_0113_false_positives.csv
#   Particles: EMD-2984_0113.csv
#
# EMD-2984_0114
#   Micrograph: EMD-2984_0114.mrc
#   False positives: EMD-2984_0114_false_positives.csv
#   Particles: EMD-2984_0114.csv
#
# EMD-2984_0115
#   Micrograph: EMD-2984_0115.mrc
#   False positives: EMD-2984_0115_false_positives.csv
#   Particles: EMD-2984_0115.csv
#
# EMD-2984_0116
#   Micrograph: EMD-2984_0116.mrc
#   False positives: EMD-2984_0116_false_positives.csv
#   Particles: EMD-2984_0116.csv
#
# EMD-2984_0117
#   Micrograph: EMD-2984_0117.mrc
#   False positives: EMD-2984_0117_false_positives.csv
#   Particles: EMD-2984_0117.csv
#
# EMD-2984_0118
#   Micrograph: EMD-2984_0118.mrc
#   False positives: EMD-2984_0118_false_positives.csv
#   Particles: EMD-2984_0118.csv
#
# EMD-2984_0119
#   Micrograph: EMD-2984_0119.mrc
#   False positives: EMD-2984_0119_false_positives.csv
#   Particles: EMD-2984_0119.csv
#
# EMD-2984_0120
#   Micrograph: EMD-2984_0120.mrc
#   False positives: EMD-2984_0120_false_positives.csv
#   Particles: EMD-2984_0120.csv
#
# EMD-2984_0121
#   Micrograph: EMD-2984_0121.mrc
#   False positives: EMD-2984_0121_false_positives.csv
#   Particles: EMD-2984_0121.csv
#
# EMD-2984_0122
#   Micrograph: EMD-2984_0122.mrc
#   False positives: EMD-2984_0122_false_positives.csv
#   Particles: EMD-2984_0122.csv
#
# EMD-2984_0123
#   Micrograph: EMD-2984_0123.mrc
#   False positives: EMD-2984_0123_false_positives.csv
#   Particles: EMD-2984_0123.csv
#
# EMD-2984_0124
#   Micrograph: EMD-2984_0124.mrc
#   False positives: EMD-2984_0124_false_positives.csv
#   Particles: EMD-2984_0124.csv
#
# EMD-2984_0125
#   Micrograph: EMD-2984_0125.mrc
#   False positives: EMD-2984_0125_false_positives.csv
#   Particles: EMD-2984_0125.csv
#
# EMD-2984_0126
#   Micrograph: EMD-2984_0126.mrc
#   False positives: EMD-2984_0126_false_positives.csv
#   Particles: EMD-2984_0126.csv
#
# EMD-2984_0127
#   Micrograph: EMD-2984_0127.mrc
#   False positives: EMD-2984_0127_false_positives.csv
#   Particles: EMD-2984_0127.csv
#
# EMD-2984_0128
#   Micrograph: EMD-2984_0128.mrc
#   False positives: EMD-2984_0128_false_positives.csv
#   Particles: EMD-2984_0128.csv
#
# EMD-2984_0129
#   Micrograph: EMD-2984_0129.mrc
#   False positives: EMD-2984_0129_false_positives.csv
#   Particles: EMD-2984_0129.csv
#
# EMD-2984_0130
#   Micrograph: EMD-2984_0130.mrc
#   False positives: EMD-2984_0130_false_positives.csv
#   Particles: EMD-2984_0130.csv
#
# EMD-2984_0131
#   Micrograph: EMD-2984_0131.mrc
#   False positives: EMD-2984_0131_false_positives.csv
#   Particles: EMD-2984_0131.csv
#
# EMD-2984_0132
#   Micrograph: EMD-2984_0132.mrc
#   False positives: EMD-2984_0132_false_positives.csv
#   Particles: EMD-2984_0132.csv
#
# EMD-2984_0133
#   Micrograph: EMD-2984_0133.mrc
#   False positives: EMD-2984_0133_false_positives.csv
#   Particles: EMD-2984_0133.csv
#
# EMD-2984_0134
#   Micrograph: EMD-2984_0134.mrc
#   False positives: EMD-2984_0134_false_positives.csv
#   Particles: EMD-2984_0134.csv
#
# EMD-2984_0135
#   Micrograph: EMD-2984_0135.mrc
#   False positives: EMD-2984_0135_false_positives.csv
#   Particles: EMD-2984_0135.csv
#
# EMD-2984_0136
#   Micrograph: EMD-2984_0136.mrc
#   False positives: EMD-2984_0136_false_positives.csv
#   Particles: EMD-2984_0136.csv
#
# EMD-2984_0137
#   Micrograph: EMD-2984_0137.mrc
#   False positives: EMD-2984_0137_false_positives.csv
#   Particles: EMD-2984_0137.csv
#
# EMD-2984_0138
#   Micrograph: EMD-2984_0138.mrc
#   False positives: EMD-2984_0138_false_positives.csv
#   Particles: EMD-2984_0138.csv
#
# EMD-2984_0139
#   Micrograph: EMD-2984_0139.mrc
#   False positives: EMD-2984_0139_false_positives.csv
#   Particles: EMD-2984_0139.csv
#
# EMD-2984_0140
#   Micrograph: EMD-2984_0140.mrc
#   False positives: EMD-2984_0140_false_positives.csv
#   Particles: EMD-2984_0140.csv
#
# EMD-2984_0141
#   Micrograph: EMD-2984_0141.mrc
#   False positives: EMD-2984_0141_false_positives.csv
#   Particles: EMD-2984_0141.csv
#
# EMD-2984_0142
#   Micrograph: EMD-2984_0142.mrc
#   False positives: EMD-2984_0142_false_positives.csv
#   Particles: EMD-2984_0142.csv
#
# EMD-2984_0143
#   Micrograph: EMD-2984_0143.mrc
#   False positives: EMD-2984_0143_false_positives.csv
#   Particles: EMD-2984_0143.csv
#
# EMD-2984_0144
#   Micrograph: EMD-2984_0144.mrc
#   False positives: EMD-2984_0144_false_positives.csv
#   Particles: EMD-2984_0144.csv
#
# EMD-2984_0145
#   Micrograph: EMD-2984_0145.mrc
#   False positives: EMD-2984_0145_false_positives.csv
#   Particles: EMD-2984_0145.csv
#
# EMD-2984_0146
#   Micrograph: EMD-2984_0146.mrc
#   False positives: EMD-2984_0146_false_positives.csv
#   Particles: EMD-2984_0146.csv
#
# EMD-2984_0147
#   Micrograph: EMD-2984_0147.mrc
#   False positives: EMD-2984_0147_false_positives.csv
#   Particles: EMD-2984_0147.csv
#
# EMD-2984_0148
#   Micrograph: EMD-2984_0148.mrc
#   False positives: EMD-2984_0148_false_positives.csv
#   Particles: EMD-2984_0148.csv
#
# EMD-2984_0149
#   Micrograph: EMD-2984_0149.mrc
#   False positives: EMD-2984_0149_false_positives.csv
#   Particles: EMD-2984_0149.csv
#
# EMD-2984_0150
#   Micrograph: EMD-2984_0150.mrc
#   False positives: EMD-2984_0150_false_positives.csv
#   Particles: EMD-2984_0150.csv
#
# EMD-2984_0151
#   Micrograph: EMD-2984_0151.mrc
#   False positives: EMD-2984_0151_false_positives.csv
#   Particles: EMD-2984_0151.csv
#
# EMD-2984_0152
#   Micrograph: EMD-2984_0152.mrc
#   False positives: EMD-2984_0152_false_positives.csv
#   Particles: EMD-2984_0152.csv
#
# EMD-2984_0153
#   Micrograph: EMD-2984_0153.mrc
#   False positives: EMD-2984_0153_false_positives.csv
#   Particles: EMD-2984_0153.csv
#
# EMD-2984_0154
#   Micrograph: EMD-2984_0154.mrc
#   False positives: EMD-2984_0154_false_positives.csv
#   Particles: EMD-2984_0154.csv
#
# EMD-2984_0155
#   Micrograph: EMD-2984_0155.mrc
#   False positives: EMD-2984_0155_false_positives.csv
#   Particles: EMD-2984_0155.csv
#
# EMD-2984_0156
#   Micrograph: EMD-2984_0156.mrc
#   False positives: EMD-2984_0156_false_positives.csv
#   Particles: EMD-2984_0156.csv
#
# EMD-2984_0157
#   Micrograph: EMD-2984_0157.mrc
#   False positives: EMD-2984_0157_false_positives.csv
#   Particles: EMD-2984_0157.csv
#
# EMD-2984_0158
#   Micrograph: EMD-2984_0158.mrc
#   False positives: EMD-2984_0158_false_positives.csv
#   Particles: EMD-2984_0158.csv
#
# EMD-2984_0159
#   Micrograph: EMD-2984_0159.mrc
#   False positives: EMD-2984_0159_false_positives.csv
#   Particles: EMD-2984_0159.csv
#
# EMD-2984_0160
#   Micrograph: EMD-2984_0160.mrc
#   False positives: EMD-2984_0160_false_positives.csv
#   Particles: EMD-2984_0160.csv
#
# EMD-2984_0161
#   Micrograph: EMD-2984_0161.mrc
#   False positives: EMD-2984_0161_false_positives.csv
#   Particles: EMD-2984_0161.csv
#
# EMD-2984_0162
#   Micrograph: EMD-2984_0162.mrc
#   False positives: EMD-2984_0162_false_positives.csv
#   Particles: EMD-2984_0162.csv
#
# EMD-2984_0163
#   Micrograph: EMD-2984_0163.mrc
#   False positives: EMD-2984_0163_false_positives.csv
#   Particles: EMD-2984_0163.csv
#
# EMD-2984_0164
#   Micrograph: EMD-2984_0164.mrc
#   False positives: EMD-2984_0164_false_positives.csv
#   Particles: EMD-2984_0164.csv
#
# EMD-2984_0165
#   Micrograph: EMD-2984_0165.mrc
#   False positives: EMD-2984_0165_false_positives.csv
#   Particles: EMD-2984_0165.csv
#
# EMD-2984_0166
#   Micrograph: EMD-2984_0166.mrc
#   False positives: EMD-2984_0166_false_positives.csv
#   Particles: EMD-2984_0166.csv
#
# EMD-2984_0167
#   Micrograph: EMD-2984_0167.mrc
#   False positives: EMD-2984_0167_false_positives.csv
#   Particles: EMD-2984_0167.csv
#
# EMD-2984_0168
#   Micrograph: EMD-2984_0168.mrc
#   False positives: EMD-2984_0168_false_positives.csv
#   Particles: EMD-2984_0168.csv
#
# EMD-2984_0169
#   Micrograph: EMD-2984_0169.mrc
#   False positives: EMD-2984_0169_false_positives.csv
#   Particles: EMD-2984_0169.csv
#
# EMD-2984_0170
#   Micrograph: EMD-2984_0170.mrc
#   False positives: EMD-2984_0170_false_positives.csv
#   Particles: EMD-2984_0170.csv
#
# EMD-2984_0171
#   Micrograph: EMD-2984_0171.mrc
#   False positives: EMD-2984_0171_false_positives.csv
#   Particles: EMD-2984_0171.csv
#
# EMD-2984_0172
#   Micrograph: EMD-2984_0172.mrc
#   False positives: EMD-2984_0172_false_positives.csv
#   Particles: EMD-2984_0172.csv
#
# EMD-2984_0173
#   Micrograph: EMD-2984_0173.mrc
#   False positives: EMD-2984_0173_false_positives.csv
#   Particles: EMD-2984_0173.csv
#
# EMD-2984_0174
#   Micrograph: EMD-2984_0174.mrc
#   False positives: EMD-2984_0174_false_positives.csv
#   Particles: EMD-2984_0174.csv
#
# EMD-2984_0175
#   Micrograph: EMD-2984_0175.mrc
#   False positives: EMD-2984_0175_false_positives.csv
#   Particles: EMD-2984_0175.csv
#
# EMD-2984_0176
#   Micrograph: EMD-2984_0176.mrc
#   False positives: EMD-2984_0176_false_positives.csv
#   Particles: EMD-2984_0176.csv
#
# EMD-2984_0177
#   Micrograph: EMD-2984_0177.mrc
#   False positives: EMD-2984_0177_false_positives.csv
#   Particles: EMD-2984_0177.csv
#
# EMD-2984_0178
#   Micrograph: EMD-2984_0178.mrc
#   False positives: EMD-2984_0178_false_positives.csv
#   Particles: EMD-2984_0178.csv
#
# EMD-2984_0179
#   Micrograph: EMD-2984_0179.mrc
#   False positives: EMD-2984_0179_false_positives.csv
#   Particles: EMD-2984_0179.csv
#
# EMD-2984_0180
#   Micrograph: EMD-2984_0180.mrc
#   False positives: EMD-2984_0180_false_positives.csv
#   Particles: EMD-2984_0180.csv
#
# EMD-2984_0181
#   Micrograph: EMD-2984_0181.mrc
#   False positives: EMD-2984_0181_false_positives.csv
#   Particles: EMD-2984_0181.csv
#
# EMD-2984_0182
#   Micrograph: EMD-2984_0182.mrc
#   False positives: EMD-2984_0182_false_positives.csv
#   Particles: EMD-2984_0182.csv
#
# EMD-2984_0183
#   Micrograph: EMD-2984_0183.mrc
#   False positives: EMD-2984_0183_false_positives.csv
#   Particles: EMD-2984_0183.csv
#
# EMD-2984_0184
#   Micrograph: EMD-2984_0184.mrc
#   False positives: EMD-2984_0184_false_positives.csv
#   Particles: EMD-2984_0184.csv
#
# EMD-2984_0185
#   Micrograph: EMD-2984_0185.mrc
#   False positives: EMD-2984_0185_false_positives.csv
#   Particles: EMD-2984_0185.csv
#
# EMD-2984_0186
#   Micrograph: EMD-2984_0186.mrc
#   False positives: EMD-2984_0186_false_positives.csv
#   Particles: EMD-2984_0186.csv
#
# EMD-2984_0187
#   Micrograph: EMD-2984_0187.mrc
#   False positives: EMD-2984_0187_false_positives.csv
#   Particles: EMD-2984_0187.csv
#
# EMD-2984_0188
#   Micrograph: EMD-2984_0188.mrc
#   False positives: EMD-2984_0188_false_positives.csv
#   Particles: EMD-2984_0188.csv
#
# EMD-2984_0189
#   Micrograph: EMD-2984_0189.mrc
#   False positives: EMD-2984_0189_false_positives.csv
#   Particles: EMD-2984_0189.csv
#
# EMD-2984_0190
#   Micrograph: EMD-2984_0190.mrc
#   False positives: EMD-2984_0190_false_positives.csv
#   Particles: EMD-2984_0190.csv
#
# EMD-2984_0191
#   Micrograph: EMD-2984_0191.mrc
#   False positives: EMD-2984_0191_false_positives.csv
#   Particles: EMD-2984_0191.csv
#
# EMD-2984_0192
#   Micrograph: EMD-2984_0192.mrc
#   False positives: EMD-2984_0192_false_positives.csv
#   Particles: EMD-2984_0192.csv
#
# EMD-2984_0193
#   Micrograph: EMD-2984_0193.mrc
#   False positives: EMD-2984_0193_false_positives.csv
#   Particles: EMD-2984_0193.csv
#
# EMD-2984_0194
#   Micrograph: EMD-2984_0194.mrc
#   False positives: EMD-2984_0194_false_positives.csv
#   Particles: EMD-2984_0194.csv
#
# EMD-2984_0195
#   Micrograph: EMD-2984_0195.mrc
#   False positives: EMD-2984_0195_false_positives.csv
#   Particles: EMD-2984_0195.csv
#
# EMD-2984_0196
#   Micrograph: EMD-2984_0196.mrc
#   False positives: EMD-2984_0196_false_positives.csv
#   Particles: EMD-2984_0196.csv
#
# EMD-2984_0197
#   Micrograph: EMD-2984_0197.mrc
#   False positives: EMD-2984_0197_false_positives.csv
#   Particles: EMD-2984_0197.csv
#
# EMD-2984_0198
#   Micrograph: EMD-2984_0198.mrc
#   False positives: EMD-2984_0198_false_positives.csv
#   Particles: EMD-2984_0198.csv
#
# EMD-2984_0199
#   Micrograph: EMD-2984_0199.mrc
#   False positives: EMD-2984_0199_false_positives.csv
#   Particles: EMD-2984_0199.csv
#
# EMD-2984_0200
#   Micrograph: EMD-2984_0200.mrc
#   False positives: EMD-2984_0200_false_positives.csv
#   Particles: EMD-2984_0200.csv
#
# EMD-2984_0201
#   Micrograph: EMD-2984_0201.mrc
#   False positives: EMD-2984_0201_false_positives.csv
#   Particles: EMD-2984_0201.csv
#
# EMD-2984_0202
#   Micrograph: EMD-2984_0202.mrc
#   False positives: EMD-2984_0202_false_positives.csv
#   Particles: EMD-2984_0202.csv
#
# EMD-2984_0203
#   Micrograph: EMD-2984_0203.mrc
#   False positives: EMD-2984_0203_false_positives.csv
#   Particles: EMD-2984_0203.csv
#
# EMD-2984_0204
#   Micrograph: EMD-2984_0204.mrc
#   False positives: EMD-2984_0204_false_positives.csv
#   Particles: EMD-2984_0204.csv
#
# EMD-2984_0205
#   Micrograph: EMD-2984_0205.mrc
#   False positives: EMD-2984_0205_false_positives.csv
#   Particles: EMD-2984_0205.csv
#
# EMD-2984_0206
#   Micrograph: EMD-2984_0206.mrc
#   False positives: EMD-2984_0206_false_positives.csv
#   Particles: EMD-2984_0206.csv
#
# EMD-2984_0207
#   Micrograph: EMD-2984_0207.mrc
#   False positives: EMD-2984_0207_false_positives.csv
#   Particles: EMD-2984_0207.csv
#
# EMD-2984_0208
#   Micrograph: EMD-2984_0208.mrc
#   False positives: EMD-2984_0208_false_positives.csv
#   Particles: EMD-2984_0208.csv
#
# EMD-2984_0209
#   Micrograph: EMD-2984_0209.mrc
#   False positives: EMD-2984_0209_false_positives.csv
#   Particles: EMD-2984_0209.csv
#
# EMD-2984_0210
#   Micrograph: EMD-2984_0210.mrc
#   False positives: EMD-2984_0210_false_positives.csv
#   Particles: EMD-2984_0210.csv
#
# EMD-2984_0211
#   Micrograph: EMD-2984_0211.mrc
#   False positives: EMD-2984_0211_false_positives.csv
#   Particles: EMD-2984_0211.csv
#
# EMD-2984_0212
#   Micrograph: EMD-2984_0212.mrc
#   False positives: EMD-2984_0212_false_positives.csv
#   Particles: EMD-2984_0212.csv
#
# EMD-2984_0213
#   Micrograph: EMD-2984_0213.mrc
#   False positives: EMD-2984_0213_false_positives.csv
#   Particles: EMD-2984_0213.csv
#
# EMD-2984_0214
#   Micrograph: EMD-2984_0214.mrc
#   False positives: EMD-2984_0214_false_positives.csv
#   Particles: EMD-2984_0214.csv
#
# EMD-2984_0215
#   Micrograph: EMD-2984_0215.mrc
#   False positives: EMD-2984_0215_false_positives.csv
#   Particles: EMD-2984_0215.csv
#
# EMD-2984_0216
#   Micrograph: EMD-2984_0216.mrc
#   False positives: EMD-2984_0216_false_positives.csv
#   Particles: EMD-2984_0216.csv
#
# EMD-2984_0217
#   Micrograph: EMD-2984_0217.mrc
#   False positives: EMD-2984_0217_false_positives.csv
#   Particles: EMD-2984_0217.csv
#
# EMD-2984_0218
#   Micrograph: EMD-2984_0218.mrc
#   False positives: EMD-2984_0218_false_positives.csv
#   Particles: EMD-2984_0218.csv
#
# EMD-2984_0219
#   Micrograph: EMD-2984_0219.mrc
#   False positives: EMD-2984_0219_false_positives.csv
#   Particles: EMD-2984_0219.csv
#
# EMD-2984_0220
#   Micrograph: EMD-2984_0220.mrc
#   False positives: EMD-2984_0220_false_positives.csv
#   Particles: EMD-2984_0220.csv
#
# EMD-2984_0221
#   Micrograph: EMD-2984_0221.mrc
#   False positives: EMD-2984_0221_false_positives.csv
#   Particles: EMD-2984_0221.csv
#
# EMD-2984_0222
#   Micrograph: EMD-2984_0222.mrc
#   False positives: EMD-2984_0222_false_positives.csv
#   Particles: EMD-2984_0222.csv
#
# EMD-2984_0223
#   Micrograph: EMD-2984_0223.mrc
#   False positives: EMD-2984_0223_false_positives.csv
#   Particles: EMD-2984_0223.csv
#
# EMD-2984_0224
#   Micrograph: EMD-2984_0224.mrc
#   False positives: EMD-2984_0224_false_positives.csv
#   Particles: EMD-2984_0224.csv
#
# EMD-2984_0225
#   Micrograph: EMD-2984_0225.mrc
#   False positives: EMD-2984_0225_false_positives.csv
#   Particles: EMD-2984_0225.csv
#
# EMD-2984_0226
#   Micrograph: EMD-2984_0226.mrc
#   False positives: EMD-2984_0226_false_positives.csv
#   Particles: EMD-2984_0226.csv
#
# EMD-2984_0227
#   Micrograph: EMD-2984_0227.mrc
#   False positives: EMD-2984_0227_false_positives.csv
#   Particles: EMD-2984_0227.csv
#
# EMD-2984_0228
#   Micrograph: EMD-2984_0228.mrc
#   False positives: EMD-2984_0228_false_positives.csv
#   Particles: EMD-2984_0228.csv
#
# EMD-2984_0229
#   Micrograph: EMD-2984_0229.mrc
#   False positives: EMD-2984_0229_false_positives.csv
#   Particles: EMD-2984_0229.csv
#
# EMD-2984_0230
#   Micrograph: EMD-2984_0230.mrc
#   False positives: EMD-2984_0230_false_positives.csv
#   Particles: EMD-2984_0230.csv
#
# EMD-2984_0231
#   Micrograph: EMD-2984_0231.mrc
#   False positives: EMD-2984_0231_false_positives.csv
#   Particles: EMD-2984_0231.csv
#
# EMD-2984_0232
#   Micrograph: EMD-2984_0232.mrc
#   False positives: EMD-2984_0232_false_positives.csv
#   Particles: EMD-2984_0232.csv
#
# EMD-2984_0233
#   Micrograph: EMD-2984_0233.mrc
#   False positives: EMD-2984_0233_false_positives.csv
#   Particles: EMD-2984_0233.csv
#
# EMD-2984_0234
#   Micrograph: EMD-2984_0234.mrc
#   False positives: EMD-2984_0234_false_positives.csv
#   Particles: EMD-2984_0234.csv
#
# EMD-2984_0235
#   Micrograph: EMD-2984_0235.mrc
#   False positives: EMD-2984_0235_false_positives.csv
#   Particles: EMD-2984_0235.csv
#
# EMD-2984_0236
#   Micrograph: EMD-2984_0236.mrc
#   False positives: EMD-2984_0236_false_positives.csv
#   Particles: EMD-2984_0236.csv
#
# EMD-2984_0237
#   Micrograph: EMD-2984_0237.mrc
#   False positives: EMD-2984_0237_false_positives.csv
#   Particles: EMD-2984_0237.csv
#
# EMD-2984_0238
#   Micrograph: EMD-2984_0238.mrc
#   False positives: EMD-2984_0238_false_positives.csv
#   Particles: EMD-2984_0238.csv
#
# EMD-2984_0239
#   Micrograph: EMD-2984_0239.mrc
#   False positives: EMD-2984_0239_false_positives.csv
#   Particles: EMD-2984_0239.csv
#
# EMD-2984_0240
#   Micrograph: EMD-2984_0240.mrc
#   False positives: EMD-2984_0240_false_positives.csv
#   Particles: EMD-2984_0240.csv
#
# EMD-2984_0241
#   Micrograph: EMD-2984_0241.mrc
#   False positives: EMD-2984_0241_false_positives.csv
#   Particles: EMD-2984_0241.csv
#
# EMD-2984_0242
#   Micrograph: EMD-2984_0242.mrc
#   False positives: EMD-2984_0242_false_positives.csv
#   Particles: EMD-2984_0242.csv
#
# EMD-2984_0243
#   Micrograph: EMD-2984_0243.mrc
#   False positives: EMD-2984_0243_false_positives.csv
#   Particles: EMD-2984_0243.csv
#
# EMD-2984_0244
#   Micrograph: EMD-2984_0244.mrc
#   False positives: EMD-2984_0244_false_positives.csv
#   Particles: EMD-2984_0244.csv
#
# EMD-2984_0245
#   Micrograph: EMD-2984_0245.mrc
#   False positives: EMD-2984_0245_false_positives.csv
#   Particles: EMD-2984_0245.csv
#
# EMD-2984_0246
#   Micrograph: EMD-2984_0246.mrc
#   False positives: EMD-2984_0246_false_positives.csv
#   Particles: EMD-2984_0246.csv
#
# EMD-2984_0247
#   Micrograph: EMD-2984_0247.mrc
#   False positives: EMD-2984_0247_false_positives.csv
#   Particles: EMD-2984_0247.csv
#
# EMD-2984_0248
#   Micrograph: EMD-2984_0248.mrc
#   False positives: EMD-2984_0248_false_positives.csv
#   Particles: EMD-2984_0248.csv
#
# EMD-2984_0249
#   Micrograph: EMD-2984_0249.mrc
#   False positives: EMD-2984_0249_false_positives.csv
#   Particles: EMD-2984_0249.csv
#
# EMD-2984_0250
#   Micrograph: EMD-2984_0250.mrc
#   False positives: EMD-2984_0250_false_positives.csv
#   Particles: EMD-2984_0250.csv
#
# EMD-2984_0251
#   Micrograph: EMD-2984_0251.mrc
#   False positives: EMD-2984_0251_false_positives.csv
#   Particles: EMD-2984_0251.csv
#
# EMD-2984_0252
#   Micrograph: EMD-2984_0252.mrc
#   False positives: EMD-2984_0252_false_positives.csv
#   Particles: EMD-2984_0252.csv
#
# EMD-2984_0253
#   Micrograph: EMD-2984_0253.mrc
#   False positives: EMD-2984_0253_false_positives.csv
#   Particles: EMD-2984_0253.csv
#
# EMD-2984_0254
#   Micrograph: EMD-2984_0254.mrc
#   False positives: EMD-2984_0254_false_positives.csv
#   Particles: EMD-2984_0254.csv
#
# EMD-2984_0255
#   Micrograph: EMD-2984_0255.mrc
#   False positives: EMD-2984_0255_false_positives.csv
#   Particles: EMD-2984_0255.csv
#
# EMD-2984_0256
#   Micrograph: EMD-2984_0256.mrc
#   False positives: EMD-2984_0256_false_positives.csv
#   Particles: EMD-2984_0256.csv
#
# EMD-2984_0257
#   Micrograph: EMD-2984_0257.mrc
#   False positives: EMD-2984_0257_false_positives.csv
#   Particles: EMD-2984_0257.csv
#
# EMD-2984_0258
#   Micrograph: EMD-2984_0258.mrc
#   False positives: EMD-2984_0258_false_positives.csv
#   Particles: EMD-2984_0258.csv
#
# EMD-2984_0259
#   Micrograph: EMD-2984_0259.mrc
#   False positives: EMD-2984_0259_false_positives.csv
#   Particles: EMD-2984_0259.csv
#
# EMD-2984_0260
#   Micrograph: EMD-2984_0260.mrc
#   False positives: EMD-2984_0260_false_positives.csv
#   Particles: EMD-2984_0260.csv
#
# EMD-2984_0261
#   Micrograph: EMD-2984_0261.mrc
#   False positives: EMD-2984_0261_false_positives.csv
#   Particles: EMD-2984_0261.csv
#
# EMD-2984_0262
#   Micrograph: EMD-2984_0262.mrc
#   False positives: EMD-2984_0262_false_positives.csv
#   Particles: EMD-2984_0262.csv
#
# EMD-2984_0263
#   Micrograph: EMD-2984_0263.mrc
#   False positives: EMD-2984_0263_false_positives.csv
#   Particles: EMD-2984_0263.csv
#
# EMD-2984_0264
#   Micrograph: EMD-2984_0264.mrc
#   False positives: EMD-2984_0264_false_positives.csv
#   Particles: EMD-2984_0264.csv
#
# EMD-2984_0265
#   Micrograph: EMD-2984_0265.mrc
#   False positives: EMD-2984_0265_false_positives.csv
#   Particles: EMD-2984_0265.csv
#
# EMD-2984_0266
#   Micrograph: EMD-2984_0266.mrc
#   False positives: EMD-2984_0266_false_positives.csv
#   Particles: EMD-2984_0266.csv
#
# EMD-2984_0267
#   Micrograph: EMD-2984_0267.mrc
#   False positives: EMD-2984_0267_false_positives.csv
#   Particles: EMD-2984_0267.csv
#
# EMD-2984_0268
#   Micrograph: EMD-2984_0268.mrc
#   False positives: EMD-2984_0268_false_positives.csv
#   Particles: EMD-2984_0268.csv
#
# EMD-2984_0269
#   Micrograph: EMD-2984_0269.mrc
#   False positives: EMD-2984_0269_false_positives.csv
#   Particles: EMD-2984_0269.csv
#
# EMD-2984_0270
#   Micrograph: EMD-2984_0270.mrc
#   False positives: EMD-2984_0270_false_positives.csv
#   Particles: EMD-2984_0270.csv
#
# EMD-2984_0271
#   Micrograph: EMD-2984_0271.mrc
#   False positives: EMD-2984_0271_false_positives.csv
#   Particles: EMD-2984_0271.csv
#
# EMD-2984_0272
#   Micrograph: EMD-2984_0272.mrc
#   False positives: EMD-2984_0272_false_positives.csv
#   Particles: EMD-2984_0272.csv
#
# EMD-2984_0273
#   Micrograph: EMD-2984_0273.mrc
#   False positives: EMD-2984_0273_false_positives.csv
#   Particles: EMD-2984_0273.csv
#
# EMD-2984_0274
#   Micrograph: EMD-2984_0274.mrc
#   False positives: EMD-2984_0274_false_positives.csv
#   Particles: EMD-2984_0274.csv
#
# EMD-2984_0275
#   Micrograph: EMD-2984_0275.mrc
#   False positives: EMD-2984_0275_false_positives.csv
#   Particles: EMD-2984_0275.csv
#
# EMD-2984_0276
#   Micrograph: EMD-2984_0276.mrc
#   False positives: EMD-2984_0276_false_positives.csv
#   Particles: EMD-2984_0276.csv
#
# EMD-2984_0277
#   Micrograph: EMD-2984_0277.mrc
#   False positives: EMD-2984_0277_false_positives.csv
#   Particles: EMD-2984_0277.csv
#
# EMD-2984_0278
#   Micrograph: EMD-2984_0278.mrc
#   False positives: EMD-2984_0278_false_positives.csv
#   Particles: EMD-2984_0278.csv
#
# EMD-2984_0279
#   Micrograph: EMD-2984_0279.mrc
#   False positives: EMD-2984_0279_false_positives.csv
#   Particles: EMD-2984_0279.csv
#
# EMD-2984_0280
#   Micrograph: EMD-2984_0280.mrc
#   False positives: EMD-2984_0280_false_positives.csv
#   Particles: EMD-2984_0280.csv
#
# EMD-2984_0281
#   Micrograph: EMD-2984_0281.mrc
#   False positives: EMD-2984_0281_false_positives.csv
#   Particles: EMD-2984_0281.csv
#
# EMD-2984_0282
#   Micrograph: EMD-2984_0282.mrc
#   False positives: EMD-2984_0282_false_positives.csv
#   Particles: EMD-2984_0282.csv
#
# EMD-2984_0283
#   Micrograph: EMD-2984_0283.mrc
#   False positives: EMD-2984_0283_false_positives.csv
#   Particles: EMD-2984_0283.csv
#
# EMD-2984_0284
#   Micrograph: EMD-2984_0284.mrc
#   False positives: EMD-2984_0284_false_positives.csv
#   Particles: EMD-2984_0284.csv
#
# EMD-2984_0285
#   Micrograph: EMD-2984_0285.mrc
#   False positives: EMD-2984_0285_false_positives.csv
#   Particles: EMD-2984_0285.csv
#
# EMD-2984_0286
#   Micrograph: EMD-2984_0286.mrc
#   False positives: EMD-2984_0286_false_positives.csv
#   Particles: EMD-2984_0286.csv
#
# EMD-2984_0287
#   Micrograph: EMD-2984_0287.mrc
#   False positives: EMD-2984_0287_false_positives.csv
#   Particles: EMD-2984_0287.csv
#
# EMD-2984_0288
#   Micrograph: EMD-2984_0288.mrc
#   False positives: EMD-2984_0288_false_positives.csv
#   Particles: EMD-2984_0288.csv
#
# EMD-2984_0289
#   Micrograph: EMD-2984_0289.mrc
#   False positives: EMD-2984_0289_false_positives.csv
#   Particles: EMD-2984_0289.csv
#
# EMD-2984_0290
#   Micrograph: EMD-2984_0290.mrc
#   False positives: EMD-2984_0290_false_positives.csv
#   Particles: EMD-2984_0290.csv
#
# EMD-2984_0291
#   Micrograph: EMD-2984_0291.mrc
#   False positives: EMD-2984_0291_false_positives.csv
#   Particles: EMD-2984_0291.csv
#
# EMD-2984_0292
#   Micrograph: EMD-2984_0292.mrc
#   False positives: EMD-2984_0292_false_positives.csv
#   Particles: EMD-2984_0292.csv
#
# EMD-2984_0293
#   Micrograph: EMD-2984_0293.mrc
#   False positives: EMD-2984_0293_false_positives.csv
#   Particles: EMD-2984_0293.csv
#
# EMD-2984_0294
#   Micrograph: EMD-2984_0294.mrc
#   False positives: EMD-2984_0294_false_positives.csv
#   Particles: EMD-2984_0294.csv
#
# EMD-2984_0295
#   Micrograph: EMD-2984_0295.mrc
#   False positives: EMD-2984_0295_false_positives.csv
#   Particles: EMD-2984_0295.csv
#
# EMD-2984_0296
#   Micrograph: EMD-2984_0296.mrc
#   False positives: EMD-2984_0296_false_positives.csv
#   Particles: EMD-2984_0296.csv
#
# EMD-2984_0297
#   Micrograph: EMD-2984_0297.mrc
#   False positives: EMD-2984_0297_false_positives.csv
#   Particles: EMD-2984_0297.csv
#
# EMD-2984_0298
#   Micrograph: EMD-2984_0298.mrc
#   False positives: EMD-2984_0298_false_positives.csv
#   Particles: EMD-2984_0298.csv
#
# EMD-2984_0299
#   Micrograph: EMD-2984_0299.mrc
#   False positives: EMD-2984_0299_false_positives.csv
#   Particles: EMD-2984_0299.csv
#
# EMD-2984_0300
#   Micrograph: EMD-2984_0300.mrc
#   False positives: EMD-2984_0300_false_positives.csv
#   Particles: EMD-2984_0300.csv
#
# EMD-2984_0301
#   Micrograph: EMD-2984_0301.mrc
#   False positives: EMD-2984_0301_false_positives.csv
#   Particles: EMD-2984_0301.csv
#
# EMD-2984_0302
#   Micrograph: EMD-2984_0302.mrc
#   False positives: EMD-2984_0302_false_positives.csv
#   Particles: EMD-2984_0302.csv
#
# EMD-2984_0303
#   Micrograph: EMD-2984_0303.mrc
#   False positives: EMD-2984_0303_false_positives.csv
#   Particles: EMD-2984_0303.csv
#
# EMD-2984_0304
#   Micrograph: EMD-2984_0304.mrc
#   False positives: EMD-2984_0304_false_positives.csv
#   Particles: EMD-2984_0304.csv
#
# EMD-2984_0305
#   Micrograph: EMD-2984_0305.mrc
#   False positives: EMD-2984_0305_false_positives.csv
#   Particles: EMD-2984_0305.csv
#
# EMD-2984_0306
#   Micrograph: EMD-2984_0306.mrc
#   False positives: EMD-2984_0306_false_positives.csv
#   Particles: EMD-2984_0306.csv
#
# EMD-2984_0307
#   Micrograph: EMD-2984_0307.mrc
#   False positives: EMD-2984_0307_false_positives.csv
#   Particles: EMD-2984_0307.csv
#
# EMD-2984_0308
#   Micrograph: EMD-2984_0308.mrc
#   False positives: EMD-2984_0308_false_positives.csv
#   Particles: EMD-2984_0308.csv
#
# EMD-2984_0309
#   Micrograph: EMD-2984_0309.mrc
#   False positives: EMD-2984_0309_false_positives.csv
#   Particles: EMD-2984_0309.csv
#
# EMD-2984_0310
#   Micrograph: EMD-2984_0310.mrc
#   False positives: EMD-2984_0310_false_positives.csv
#   Particles: EMD-2984_0310.csv
#
# EMD-2984_0311
#   Micrograph: EMD-2984_0311.mrc
#   False positives: EMD-2984_0311_false_positives.csv
#   Particles: EMD-2984_0311.csv
#
# EMD-2984_0312
#   Micrograph: EMD-2984_0312.mrc
#   False positives: EMD-2984_0312_false_positives.csv
#   Particles: EMD-2984_0312.csv
#
# EMD-2984_0313
#   Micrograph: EMD-2984_0313.mrc
#   False positives: EMD-2984_0313_false_positives.csv
#   Particles: EMD-2984_0313.csv
#
# EMD-2984_0314
#   Micrograph: EMD-2984_0314.mrc
#   False positives: EMD-2984_0314_false_positives.csv
#   Particles: EMD-2984_0314.csv
#
# EMD-2984_0315
#   Micrograph: EMD-2984_0315.mrc
#   False positives: EMD-2984_0315_false_positives.csv
#   Particles: EMD-2984_0315.csv
#
# EMD-2984_0316
#   Micrograph: EMD-2984_0316.mrc
#   False positives: EMD-2984_0316_false_positives.csv
#   Particles: EMD-2984_0316.csv
#
# EMD-2984_0317
#   Micrograph: EMD-2984_0317.mrc
#   False positives: EMD-2984_0317_false_positives.csv
#   Particles: EMD-2984_0317.csv
#
# EMD-2984_0318
#   Micrograph: EMD-2984_0318.mrc
#   False positives: EMD-2984_0318_false_positives.csv
#   Particles: EMD-2984_0318.csv
#
# EMD-2984_0319
#   Micrograph: EMD-2984_0319.mrc
#   False positives: EMD-2984_0319_false_positives.csv
#   Particles: EMD-2984_0319.csv
#
# EMD-2984_0320
#   Micrograph: EMD-2984_0320.mrc
#   False positives: EMD-2984_0320_false_positives.csv
#   Particles: EMD-2984_0320.csv
#
# EMD-2984_0321
#   Micrograph: EMD-2984_0321.mrc
#   False positives: EMD-2984_0321_false_positives.csv
#   Particles: EMD-2984_0321.csv
#
# EMD-2984_0322
#   Micrograph: EMD-2984_0322.mrc
#   False positives: EMD-2984_0322_false_positives.csv
#   Particles: EMD-2984_0322.csv
#
# EMD-2984_0323
#   Micrograph: EMD-2984_0323.mrc
#   False positives: EMD-2984_0323_false_positives.csv
#   Particles: EMD-2984_0323.csv
#
# EMD-2984_0324
#   Micrograph: EMD-2984_0324.mrc
#   False positives: EMD-2984_0324_false_positives.csv
#   Particles: EMD-2984_0324.csv
#
# EMD-2984_0325
#   Micrograph: EMD-2984_0325.mrc
#   False positives: EMD-2984_0325_false_positives.csv
#   Particles: EMD-2984_0325.csv
#
# EMD-2984_0326
#   Micrograph: EMD-2984_0326.mrc
#   False positives: EMD-2984_0326_false_positives.csv
#   Particles: EMD-2984_0326.csv
#
# EMD-2984_0327
#   Micrograph: EMD-2984_0327.mrc
#   False positives: EMD-2984_0327_false_positives.csv
#   Particles: EMD-2984_0327.csv
#
# EMD-2984_0328
#   Micrograph: EMD-2984_0328.mrc
#   False positives: EMD-2984_0328_false_positives.csv
#   Particles: EMD-2984_0328.csv
#
# EMD-2984_0329
#   Micrograph: EMD-2984_0329.mrc
#   False positives: EMD-2984_0329_false_positives.csv
#   Particles: EMD-2984_0329.csv
#
# EMD-2984_0330
#   Micrograph: EMD-2984_0330.mrc
#   False positives: EMD-2984_0330_false_positives.csv
#   Particles: EMD-2984_0330.csv
#
# EMD-2984_0331
#   Micrograph: EMD-2984_0331.mrc
#   False positives: EMD-2984_0331_false_positives.csv
#   Particles: EMD-2984_0331.csv
#
# EMD-2984_0332
#   Micrograph: EMD-2984_0332.mrc
#   False positives: EMD-2984_0332_false_positives.csv
#   Particles: EMD-2984_0332.csv
#
# EMD-2984_0333
#   Micrograph: EMD-2984_0333.mrc
#   False positives: EMD-2984_0333_false_positives.csv
#   Particles: EMD-2984_0333.csv
#
# EMD-2984_0334
#   Micrograph: EMD-2984_0334.mrc
#   False positives: EMD-2984_0334_false_positives.csv
#   Particles: EMD-2984_0334.csv

# %%
###visualizing the overlay of False positives and particles

def load_micrograph(mrc_path):
    with mrcfile.open(mrc_path, permissive=True) as mrc:
        return np.array(mrc.data)

def read_xy_first_two_cols(csv_path):
    df = pd.read_csv(csv_path)
    x = pd.to_numeric(df.iloc[:, 0], errors="coerce").to_numpy()
    y = pd.to_numeric(df.iloc[:, 1], errors="coerce").to_numpy()
    mask = np.isfinite(x) & np.isfinite(y)
    return x[mask], y[mask]

#  Overlay for 5 matched micrographs 
valid_ids_sorted = sorted(valid_ids)

for stack_id in valid_ids_sorted[:5]:
    img_path = micrographs[stack_id]
    fp_csv = false_positives[stack_id]
    pc_csv = particle_coords[stack_id]

    # load micrograph
    img = load_micrograph(img_path)

    # contrast enhancement for display
    vmin, vmax = np.percentile(img, [2, 98])

    # load coordinates (first two columns are X, Y)
    px, py = read_xy_first_two_cols(pc_csv)  # particles
    fx, fy = read_xy_first_two_cols(fp_csv)  # false positives

    # plot
    plt.figure(figsize=(7, 7))
    plt.imshow(img, cmap="gray", vmin=vmin, vmax=vmax, origin="upper")

    plt.scatter(px, py, s=8, marker="o", alpha=0.6, label="Particles")
    plt.scatter(fx, fy, s=12, marker="x", alpha=0.8, label="False positives")

    plt.title(f"{stack_id}\n{img_path.name}")
    plt.axis("off")
    plt.legend(loc="lower right")
    plt.show()

# %%
###Patch sizes and output directories
patch_size = 64     # we can try 64 / 96 / 128
half = patch_size // 2

out_root = main_dir / "patches_64"
out_particles = out_root / "particles"
out_falsepos = out_root / "false_positives"

out_particles.mkdir(parents=True, exist_ok=True)
out_falsepos.mkdir(parents=True, exist_ok=True)

print("Saving to:", out_root)
# Out:
# Saving to: /home/tharushi/Desktop/hackathon/10061/patches_64

# %%
###cropping an d ormalization helper functions
def crop_patch(img, x, y, patch_size):
    """
    Crop patch centered at (x,y). Returns None if it would go out of bounds.
    """
    H, W = img.shape
    half = patch_size // 2

    xc = int(round(x))
    yc = int(round(y))

    x0, x1 = xc - half, xc + half
    y0, y1 = yc - half, yc + half

    if x0 < 0 or y0 < 0 or x1 > W or y1 > H:
        return None

    return img[y0:y1, x0:x1]


def patch_to_uint8(patch):
    """
    Convert float/int patch -> uint8 PNG-friendly image using percentile contrast.
    """
    vmin, vmax = np.percentile(patch, [2, 98])
    patch = np.clip(patch, vmin, vmax)
    patch = (patch - vmin) / (vmax - vmin + 1e-8)
    return (patch * 255).astype(np.uint8)

# %%
test_id = valid_ids_sorted[0]  # first matched stack
img_path = micrographs[test_id]
fp_csv = false_positives[test_id]
pc_csv = particle_coords[test_id]

img = load_micrograph(img_path)
px, py = read_xy_first_two_cols(pc_csv)
fx, fy = read_xy_first_two_cols(fp_csv)

# show 3 particle patches + 3 false-positive patches
import matplotlib.pyplot as plt

for (label, xs, ys) in [("particle", px, py), ("false_positive", fx, fy)]:
    shown = 0
    for i in range(len(xs)):
        patch = crop_patch(img, xs[i], ys[i], patch_size)
        if patch is None:
            continue
        h, w = patch.shape[0]//2, patch.shape[1]//2
        plt.figure(figsize=(3, 3))
        plt.imshow(patch, cmap="gray")
        plt.scatter([w], [h], c="red", s=40)  # center dot
        plt.axhline(h, linewidth=1)
        plt.axvline(w, linewidth=1)
        plt.title(f"{test_id} - {label}")
        plt.axis("off")
        plt.show()


        shown += 1
        if shown == 3:
            break
# Out:
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:206: RuntimeWarning: Map ID string not found - not an MRC file, or file is corrupt
#   warnings.warn(msg, RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:216: RuntimeWarning: Unrecognised machine stamp: 0x00 0x00 0x00 0x00
#   warnings.warn(str(err), RuntimeWarning)

# %%
####extract and save pathes for all micrgraphs

metadata_rows = []

for stack_id in valid_ids_sorted:
    img_path = micrographs[stack_id]
    fp_csv = false_positives[stack_id]
    pc_csv = particle_coords[stack_id]

    img = load_micrograph(img_path)
    H, W = img.shape

    px, py = read_xy_first_two_cols(pc_csv)
    fx, fy = read_xy_first_two_cols(fp_csv)

    # ---- Particles ----
    p_count = 0
    for i, (x, y) in enumerate(zip(px, py)):
        patch = crop_patch(img, x, y, patch_size)
        if patch is None:
            continue

        out_path = out_particles / f"{stack_id}_particle_{p_count:06d}.png"
        imageio.imwrite(out_path, patch_to_uint8(patch))

        metadata_rows.append({
            "stack_id": stack_id,
            "micrograph": img_path.name,
            "source_csv": pc_csv.name,
            "label": "particle",
            "x": float(x),
            "y": float(y),
            "patch_path": str(out_path),
            "patch_size": patch_size
        })
        p_count += 1

    # ---- False positives ----
    f_count = 0
    for i, (x, y) in enumerate(zip(fx, fy)):
        patch = crop_patch(img, x, y, patch_size)
        if patch is None:
            continue

        out_path = out_falsepos / f"{stack_id}_falsepos_{f_count:06d}.png"
        imageio.imwrite(out_path, patch_to_uint8(patch))

        metadata_rows.append({
            "stack_id": stack_id,
            "micrograph": img_path.name,
            "source_csv": fp_csv.name,
            "label": "false_positive",
            "x": float(x),
            "y": float(y),
            "patch_path": str(out_path),
            "patch_size": patch_size
        })
        f_count += 1

print(" Finished extracting patches.")
print("Total patches:", len(metadata_rows))
# Out:
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:206: RuntimeWarning: Map ID string not found - not an MRC file, or file is corrupt
#   warnings.warn(msg, RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:216: RuntimeWarning: Unrecognised machine stamp: 0x00 0x00 0x00 0x00
#   warnings.warn(str(err), RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:206: RuntimeWarning: Map ID string not found - not an MRC file, or file is corrupt
#   warnings.warn(msg, RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:216: RuntimeWarning: Unrecognised machine stamp: 0x00 0x00 0x00 0x00
#   warnings.warn(str(err), RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:206: RuntimeWarning: Map ID string not found - not an MRC file, or file is corrupt
#   warnings.warn(msg, RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:216: RuntimeWarning: Unrecognised machine stamp: 0x00 0x00 0x00 0x00
#   warnings.warn(str(err), RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:206: RuntimeWarning: Map ID string not found - not an MRC file, or file is corrupt
#   warnings.warn(msg, RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:216: RuntimeWarning: Unrecognised machine stamp: 0x00 0x00 0x00 0x00
#   warnings.warn(str(err), RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:206: RuntimeWarning: Map ID string not found - not an MRC file, or file is corrupt
#   warnings.warn(msg, RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:216: RuntimeWarning: Unrecognised machine stamp: 0x00 0x00 0x00 0x00
#   warnings.warn(str(err), RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:206: RuntimeWarning: Map ID string not found - not an MRC file, or file is corrupt
#   warnings.warn(msg, RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:216: RuntimeWarning: Unrecognised machine stamp: 0x00 0x00 0x00 0x00
#   warnings.warn(str(err), RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:206: RuntimeWarning: Map ID string not found - not an MRC file, or file is corrupt
#   warnings.warn(msg, RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:216: RuntimeWarning: Unrecognised machine stamp: 0x00 0x00 0x00 0x00
#   warnings.warn(str(err), RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:206: RuntimeWarning: Map ID string not found - not an MRC file, or file is corrupt
#   warnings.warn(msg, RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:216: RuntimeWarning: Unrecognised machine stamp: 0x00 0x00 0x00 0x00
#   warnings.warn(str(err), RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:206: RuntimeWarning: Map ID string not found - not an MRC file, or file is corrupt
#   warnings.warn(msg, RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:216: RuntimeWarning: Unrecognised machine stamp: 0x00 0x00 0x00 0x00
#   warnings.warn(str(err), RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:206: RuntimeWarning: Map ID string not found - not an MRC file, or file is corrupt
#   warnings.warn(msg, RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:216: RuntimeWarning: Unrecognised machine stamp: 0x00 0x00 0x00 0x00
#   warnings.warn(str(err), RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:206: RuntimeWarning: Map ID string not found - not an MRC file, or file is corrupt
#   warnings.warn(msg, RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:216: RuntimeWarning: Unrecognised machine stamp: 0x00 0x00 0x00 0x00
#   warnings.warn(str(err), RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:206: RuntimeWarning: Map ID string not found - not an MRC file, or file is corrupt
#   warnings.warn(msg, RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:216: RuntimeWarning: Unrecognised machine stamp: 0x00 0x00 0x00 0x00
#   warnings.warn(str(err), RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:206: RuntimeWarning: Map ID string not found - not an MRC file, or file is corrupt
#   warnings.warn(msg, RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:216: RuntimeWarning: Unrecognised machine stamp: 0x00 0x00 0x00 0x00
#   warnings.warn(str(err), RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:206: RuntimeWarning: Map ID string not found - not an MRC file, or file is corrupt
#   warnings.warn(msg, RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:216: RuntimeWarning: Unrecognised machine stamp: 0x00 0x00 0x00 0x00
#   warnings.warn(str(err), RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:206: RuntimeWarning: Map ID string not found - not an MRC file, or file is corrupt
#   warnings.warn(msg, RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:216: RuntimeWarning: Unrecognised machine stamp: 0x00 0x00 0x00 0x00
#   warnings.warn(str(err), RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:206: RuntimeWarning: Map ID string not found - not an MRC file, or file is corrupt
#   warnings.warn(msg, RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:216: RuntimeWarning: Unrecognised machine stamp: 0x00 0x00 0x00 0x00
#   warnings.warn(str(err), RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:206: RuntimeWarning: Map ID string not found - not an MRC file, or file is corrupt
#   warnings.warn(msg, RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:216: RuntimeWarning: Unrecognised machine stamp: 0x00 0x00 0x00 0x00
#   warnings.warn(str(err), RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:206: RuntimeWarning: Map ID string not found - not an MRC file, or file is corrupt
#   warnings.warn(msg, RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:216: RuntimeWarning: Unrecognised machine stamp: 0x00 0x00 0x00 0x00
#   warnings.warn(str(err), RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:206: RuntimeWarning: Map ID string not found - not an MRC file, or file is corrupt
#   warnings.warn(msg, RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:216: RuntimeWarning: Unrecognised machine stamp: 0x00 0x00 0x00 0x00
#   warnings.warn(str(err), RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:206: RuntimeWarning: Map ID string not found - not an MRC file, or file is corrupt
#   warnings.warn(msg, RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:216: RuntimeWarning: Unrecognised machine stamp: 0x00 0x00 0x00 0x00
#   warnings.warn(str(err), RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:206: RuntimeWarning: Map ID string not found - not an MRC file, or file is corrupt
#   warnings.warn(msg, RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:216: RuntimeWarning: Unrecognised machine stamp: 0x00 0x00 0x00 0x00
#   warnings.warn(str(err), RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:206: RuntimeWarning: Map ID string not found - not an MRC file, or file is corrupt
#   warnings.warn(msg, RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:216: RuntimeWarning: Unrecognised machine stamp: 0x00 0x00 0x00 0x00
#   warnings.warn(str(err), RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:206: RuntimeWarning: Map ID string not found - not an MRC file, or file is corrupt
#   warnings.warn(msg, RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:216: RuntimeWarning: Unrecognised machine stamp: 0x00 0x00 0x00 0x00
#   warnings.warn(str(err), RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:206: RuntimeWarning: Map ID string not found - not an MRC file, or file is corrupt
#   warnings.warn(msg, RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:216: RuntimeWarning: Unrecognised machine stamp: 0x00 0x00 0x00 0x00
#   warnings.warn(str(err), RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:206: RuntimeWarning: Map ID string not found - not an MRC file, or file is corrupt
#   warnings.warn(msg, RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:216: RuntimeWarning: Unrecognised machine stamp: 0x00 0x00 0x00 0x00
#   warnings.warn(str(err), RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:206: RuntimeWarning: Map ID string not found - not an MRC file, or file is corrupt
#   warnings.warn(msg, RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:216: RuntimeWarning: Unrecognised machine stamp: 0x00 0x00 0x00 0x00
#   warnings.warn(str(err), RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:206: RuntimeWarning: Map ID string not found - not an MRC file, or file is corrupt
#   warnings.warn(msg, RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:216: RuntimeWarning: Unrecognised machine stamp: 0x00 0x00 0x00 0x00
#   warnings.warn(str(err), RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:206: RuntimeWarning: Map ID string not found - not an MRC file, or file is corrupt
#   warnings.warn(msg, RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:216: RuntimeWarning: Unrecognised machine stamp: 0x00 0x00 0x00 0x00
#   warnings.warn(str(err), RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:206: RuntimeWarning: Map ID string not found - not an MRC file, or file is corrupt
#   warnings.warn(msg, RuntimeWarning)
# /home/tharushi/anaconda3/envs/hackathon/lib/python3.10/site-packages/mrcfile/mrcinterpreter.py:216: RuntimeWarning: Unrecognised machine stamp: 0x00 0x00 0x00 0x00
#   warnings.warn(str(err), RuntimeWarning)
#  Finished extracting patches.
# Total patches: 5831

# %%
meta_df = pd.DataFrame(metadata_rows)
meta_path = out_root / "patch_metadata.csv"
meta_df.to_csv(meta_path, index=False)

print("Saved metadata to:", meta_path)
print(meta_df["label"].value_counts())
# Out:
# Saved metadata to: /home/tharushi/Desktop/hackathon/10005/patches_64/patch_metadata.csv
# label
# particle          5374
# false_positive     457
# Name: count, dtype: int64
